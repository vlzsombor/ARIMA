# %%
# !pip install transformers
# !pip install datasets
# !pip install soundfile
# !pip install librosa
# Out:
# Requirement already satisfied: transformers in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (4.47.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests->transformers) (2024.12.14)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (2.0.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py39-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.11.11-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from datasets) (6.0.2)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->datasets)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.5.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets)
#   Downloading propcache-0.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets)
#   Downloading yarl-1.18.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (69 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading aiohttp-3.11.11-cp39-cp39-macosx_11_0_arm64.whl (455 kB)
# Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
# Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_arm64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 15.3 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 7.6 MB/s eta 0:00:0000:010:01m
# Downloading xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.5.0-cp39-cp39-macosx_11_0_arm64.whl (52 kB)
# Downloading multidict-6.1.0-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Downloading propcache-0.2.1-cp39-cp39-macosx_11_0_arm64.whl (45 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading yarl-1.18.3-cp39-cp39-macosx_11_0_arm64.whl (92 kB)
# Installing collected packages: pytz, xxhash, tzdata, pyarrow, propcache, multidict, fsspec, frozenlist, dill, attrs, async-timeout, aiohappyeyeballs, yarl, pandas, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# Successfully installed aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 async-timeout-5.0.1 attrs-24.3.0 datasets-3.2.0 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.9.0 multidict-6.1.0 multiprocess-0.70.16 pandas-2.2.3 propcache-0.2.1 pyarrow-18.1.0 pytz-2024.2 tzdata-2024.2 xxhash-3.5.0 yarl-1.18.3
# Collecting soundfile
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting cffi>=1.0 (from soundfile)
#   Downloading cffi-1.17.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0->soundfile)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp39-cp39-macosx_11_0_arm64.whl (178 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pycparser, cffi, soundfile
# Successfully installed cffi-1.17.1 pycparser-2.22 soundfile-0.12.1
# Collecting librosa
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (2.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (0.12.1)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from librosa) (4.12.2)
# Collecting lazy-loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from lazy-loader>=0.1->librosa) (24.2)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/hugging/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.12.14)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.0-cp39-cp39-macosx_11_0_arm64.whl (81 kB)
# Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.6 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading soxr-0.5.0.post1-cp39-cp39-macosx_11_0_arm64.whl (160 kB)
# Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 15.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: soxr, msgpack, llvmlite, lazy-loader, audioread, pooch, numba, librosa
# Successfully installed audioread-3.0.1 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.43.0 msgpack-1.1.0 numba-0.60.0 pooch-1.8.2 soxr-0.5.0.post1

# %%
from datasets import load_dataset, load_from_disk

# This dataset is a collection of different sounds of 5 seconds
# dataset = load_dataset("ashraq/esc50",
#                       split="train[0:10]")
dataset = load_from_disk("./models/ashraq/esc50/train")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       1 from datasets import load_dataset, load_from_disk
#       3 # This dataset is a collection of different sounds of 5 seconds
#       4 # dataset = load_dataset("ashraq/esc50",
#       5 #                       split="train[0:10]")
# ----> 6 dataset = load_from_disk("./models/ashraq/esc50/train")
#
# File c:\Users\ZsomborVeres-Lakos\anaconda3\envs\p39\lib\site-packages\datasets\load.py:2207, in load_from_disk(dataset_path, keep_in_memory, storage_options)
#    2205 fs, *_ = url_to_fs(dataset_path, **(storage_options or {}))
#    2206 if not fs.exists(dataset_path):
# -> 2207     raise FileNotFoundError(f"Directory {dataset_path} not found")
#    2208 if fs.isfile(posixpath.join(dataset_path, config.DATASET_INFO_FILENAME)) and fs.isfile(
#    2209     posixpath.join(dataset_path, config.DATASET_STATE_JSON_FILENAME)
#    2210 ):
#    2211     return Dataset.load_from_disk(dataset_path, keep_in_memory=keep_in_memory, storage_options=storage_options)
#
# FileNotFoundError: Directory ./models/ashraq/esc50/train not found
