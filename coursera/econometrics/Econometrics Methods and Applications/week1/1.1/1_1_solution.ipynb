# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('TrainExer11.csv', sep='	',header=0)


data = data.sort_values(by=['Expenditures'])

# %% [markdown]
# ## Make two histograms, one of expenditures and the other of age. Make also a scatter diagram with expenditures on the vertical axis versus age on the horizontal axis

# %%
data.plot(kind='scatter', x = 'Expenditures', y = 'Age')


plt.ylabel('average daily expenditures')

plt.show()

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data['Expenditures'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## In what respect do the data in this scatter diagram look different from the case of the sales and price data discussed in the lecture?

# %% [markdown]
# I think the expenditures can be classified into two different cluster.

# %% [markdown]
# ## Propose a method to analyze these data in a way that assists the travel agent in making recommendations to future clients.

# %% [markdown]
# Younger clients are more inclined two spend more on their holiday, this information can be used to recommend more expensive holiday.

# %% [markdown]
# ## (d) Compute the sample mean of expenditures of all 26 clients.

# %%
data['Expenditures'].mean(axis = 0)
# Out:
# 101.11538461538461

# %% [markdown]
# ## (e) Compute two sample means of expenditures, one for clients of age forty or more and the other for clients of age below forty.

# %%
young_mean = data[data['Age'] < 40]['Expenditures'].mean(axis=0)

old_mean = data[data['Age'] > 40]['Expenditures'].mean(axis=0)

print(f"young mean {young_mean} \nold mean {old_mean}")
# Out:
# young mean 106.38461538461539
# old mean 96.0

# %% [markdown]
# ## (f) What daily expenditures would you predict for a new client of fifty years old? And for someone who is twenty-five years old?

# %% [markdown]
# Expected expenditures
# * For 25 years old: 106.38
# * For 50 years old: 96
