# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('TrainExer11.csv', sep='	',header=1, index_col =1)

data.plot(kind='bar', )
plt.ylabel('Frequency')
plt.xlabel('Words')
plt.title('Title')

plt.show()
